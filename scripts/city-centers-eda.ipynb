# %%
import pandas as pd

# %%
df = pd.read_csv("../data/msas_with_central_city_cbds.csv")

# %%
df.head()
# Out:
#    state  placefp   cbsa stab           placenm   pop2k  popinmsa  \
# 0     48     1000  10180   TX      Abilene city  115930  115930.0
# 1     39     1000  10420   OH        Akron city  217074  217074.0
# 2     13     1052  10500   GA       Albany city   76939   76939.0
# 3     36     1000  10580   NY       Albany city   95658   95658.0
# 4     35     2000  10740   NM  Albuquerque city  448607  448607.0
#
#                                          msamdivname  countynumeric  \
# 0          Abilene, TX Metropolitan Statistical Area            441
# 1            Akron, OH Metropolitan Statistical Area            153
# 2           Albany, GA Metropolitan Statistical Area             95
# 3  Albany-Schenectady-Troy, NY Metropolitan Stati...              1
# 4      Albuquerque, NM Metropolitan Statistical Area              1
#
#          place  cbd_retail_long  cbd_retail_lat arcgis_match  arcgis_long  \
# 0      Abilene       -99.733101       32.448601            M   -99.741421
# ...
